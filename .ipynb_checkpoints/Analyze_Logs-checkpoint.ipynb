# %%
import sqlite3

# %%
import pandas as pd

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("access_logs.csv", parse_dates=["timestamp"])

# %%
df
# Out:
#           ip_address           timestamp    endpoint  response_code  \
# 0     87.223.243.247 2025-08-05 12:27:50  /dashboard            200
# 1     54.170.129.160 2025-08-05 12:25:07      /login            200
# 2     100.42.125.134 2025-08-05 12:08:25     /search            404
# 3    170.130.138.144 2025-08-05 12:27:44   /settings            500
# 4       64.35.194.81 2025-08-05 12:51:19     /search            200
# ..               ...                 ...         ...            ...
# 495    151.38.35.158 2025-08-05 12:33:11      /login            200
# 496   209.152.25.107 2025-08-05 12:39:59       /home            200
# 497   195.151.179.27 2025-08-05 12:51:38    /contact            200
# 498    96.42.128.160 2025-08-05 12:58:21      /login            403
# 499    213.118.51.97 2025-08-05 12:01:27      /login            200
#
#                           user_agent
# 0                        curl/7.68.0
# 1                        curl/7.68.0
# 2                        Mozilla/5.0
# 3             python-requests/2.25.1
# 4                 Go-http-client/1.1
# ..                               ...
# 495           python-requests/2.25.1
# 496  Mozilla/5.0 (Linux; Android 10)
# 497                      Mozilla/5.0
# 498  Mozilla/5.0 (Linux; Android 10)
# 499                             nmap
#
# [500 rows x 5 columns]

# %%
print(df.head())
# Out:
#         ip_address           timestamp    endpoint  response_code  \
# 0   87.223.243.247 2025-08-05 12:27:50  /dashboard            200
# 1   54.170.129.160 2025-08-05 12:25:07      /login            200
# 2   100.42.125.134 2025-08-05 12:08:25     /search            404
# 3  170.130.138.144 2025-08-05 12:27:44   /settings            500
# 4     64.35.194.81 2025-08-05 12:51:19     /search            200
#
#                user_agent
# 0             curl/7.68.0
# 1             curl/7.68.0
# 2             Mozilla/5.0
# 3  python-requests/2.25.1
# 4      Go-http-client/1.1

# %%
print(df.dtypes)
# Out:
# ip_address               object
# timestamp        datetime64[ns]
# endpoint                 object
# response_code             int64
# user_agent               object
# dtype: object

# %%
# Convert timestamp to string just in case
df["timestamp"] = df["timestamp"].astype(str)

# %%
# Strip weird characters from user_agent
df["user_agent"] = df["user_agent"].str.encode('utf-8', 'ignore').str.decode('utf-8')

# %%
df["endpoint"] = df["endpoint"].astype(str)

# %%
df["ip_address"] = df["ip_address"].astype(str)

# %%
conn = sqlite3.connect("threat_logs.db")

# %%
# connecting to db

# %%
df.to_sql("access_logs", conn, if_exists="replace", index=False, dtype={
    "ip_address": "TEXT",
    "timestamp": "TEXT",
    "endpoint": "TEXT",
    "response_code": "INTEGER",
    "user_agent": "TEXT"
})
# Out:
# 500

# %%
pd.read_sql_query("SELECT COUNT(*) FROM access_logs", conn)
# Out:
#    COUNT(*)
# 0       500

# %%
# checking to see data

# %%
query = """
SELECT ip_address, COUNT(*) AS admin_hit_count
FROM access_logs
WHERE endpoint = '/admin'
GROUP BY ip_address
ORDER BY admin_hit_count DESC;
"""

admin_abuse = pd.read_sql_query(query, conn)
admin_abuse
# Out:
#          ip_address  admin_hit_count
# 0    94.100.110.113                1
# 1     88.187.37.121                1
# 2      84.2.132.153                1
# 3      83.98.79.122                1
# 4     77.135.207.46                1
# 5     76.68.154.129                1
# 6       65.53.67.23                1
# 7     65.173.117.25                1
# 8     63.186.104.39                1
# 9     61.74.132.227                1
# 10    58.188.77.208                1
# 11    57.102.18.229                1
# 12     56.78.35.170                1
# 13    53.161.27.248                1
# 14    52.141.236.58                1
# 15      44.28.12.19                1
# 16    44.17.242.161                1
# 17       41.2.74.47                1
# 18   38.112.118.108                1
# 19   34.122.111.152                1
# 20   33.244.169.131                1
# 21      32.54.99.43                1
# 22    29.111.26.174                1
# 23   25.134.189.249                1
# 24    23.139.105.46                1
# 25   221.41.249.242                1
# 26     216.31.62.86                1
# 27  216.212.206.243                1
# 28    214.232.55.98                1
# 29    211.98.37.131                1
# 30  211.121.224.130                1
# 31   208.56.106.235                1
# 32    205.95.65.133                1
# 33   198.55.184.122                1
# 34    192.156.66.21                1
# 35   185.90.153.168                1
# 36    184.179.128.2                1
# 37      178.95.0.55                1
# 38   177.166.237.96                1
# 39   173.210.65.228                1
# 40   171.243.95.132                1
# 41  166.223.208.224                1
# 42  161.109.225.175                1
# 43   156.61.253.121                1
# 44    152.95.120.73                1
# 45   144.235.59.119                1
# 46   143.184.255.56                1
# 47   142.241.33.218                1
# 48  142.180.134.146                1
# 49    141.215.38.79                1
# 50   132.68.153.183                1
# 51    13.81.183.176                1
# 52   127.44.137.185                1
# 53  118.220.184.130                1
# 54   117.177.213.12                1
# 55   111.87.195.233                1
# 56   110.46.153.123                1
# 57       11.83.1.62                1
# 58    109.233.86.83                1
# 59  109.160.116.178                1

# %%
# checking to see all hits to /admin

# %%
query = """
SELECT ip_address, timestamp, user_agent
FROM access_logs
WHERE endpoint = '/admin'
GROUP BY ip_address
ORDER BY ip_address, timestamp;
"""

admin_logs = pd.read_sql_query(query, conn)
admin_logs.head(30)
# Out:
#          ip_address            timestamp                       user_agent
# 0   109.160.116.178  2025-08-05 12:14:46  Mozilla/5.0 (Linux; Android 10)
# 1     109.233.86.83  2025-08-05 12:49:55  Mozilla/5.0 (Linux; Android 10)
# 2        11.83.1.62  2025-08-05 12:02:32                      Mozilla/5.0
# 3    110.46.153.123  2025-08-05 12:14:40                      curl/7.68.0
# 4    111.87.195.233  2025-08-05 12:32:15               Go-http-client/1.1
# 5    117.177.213.12  2025-08-05 12:18:32           python-requests/2.25.1
# 6   118.220.184.130  2025-08-05 12:49:50  Mozilla/5.0 (Linux; Android 10)
# 7    127.44.137.185  2025-08-05 12:31:49               Go-http-client/1.1
# 8     13.81.183.176  2025-08-05 12:41:01                      Mozilla/5.0
# 9    132.68.153.183  2025-08-05 12:46:23                             nmap
# 10    141.215.38.79  2025-08-05 12:57:04           python-requests/2.25.1
# 11  142.180.134.146  2025-08-05 12:00:12                      curl/7.68.0
# 12   142.241.33.218  2025-08-05 12:51:01                      Mozilla/5.0
# 13   143.184.255.56  2025-08-05 12:30:26                             nmap
# 14   144.235.59.119  2025-08-05 12:47:00           python-requests/2.25.1
# 15    152.95.120.73  2025-08-05 12:39:44               Go-http-client/1.1
# 16   156.61.253.121  2025-08-05 12:02:45                             nmap
# 17  161.109.225.175  2025-08-05 12:04:14               Go-http-client/1.1
# 18  166.223.208.224  2025-08-05 12:18:13                      Mozilla/5.0
# 19   171.243.95.132  2025-08-05 12:37:30                      curl/7.68.0
# 20   173.210.65.228  2025-08-05 12:57:21           python-requests/2.25.1
# 21   177.166.237.96  2025-08-05 12:42:08                      Mozilla/5.0
# 22      178.95.0.55  2025-08-05 12:41:45                             nmap
# 23    184.179.128.2  2025-08-05 12:18:42               Go-http-client/1.1
# 24   185.90.153.168  2025-08-05 12:55:52           python-requests/2.25.1
# 25    192.156.66.21  2025-08-05 12:08:01                      Mozilla/5.0
# 26   198.55.184.122  2025-08-05 12:43:02  Mozilla/5.0 (Linux; Android 10)
# 27    205.95.65.133  2025-08-05 12:50:42                      Mozilla/5.0
# 28   208.56.106.235  2025-08-05 12:24:01           python-requests/2.25.1
# 29  211.121.224.130  2025-08-05 12:32:42  Mozilla/5.0 (Linux; Android 10)

# %%
# pull in timestamp and user agent

# %%
query = """
SELECT ip_address, user_agent, COUNT(*) AS hit_count
FROM access_logs
WHERE user_agent LIKE '%curl%'
   OR user_agent LIKE '%python%'
   OR user_agent LIKE '%nmap%'
   OR user_agent LIKE '%Go-http-client%'
GROUP BY ip_address, user_agent
ORDER BY hit_count DESC;
"""

bot_traffic = pd.read_sql_query(query, conn)
bot_traffic
# Out:
#           ip_address              user_agent  hit_count
# 0      100.60.16.155      Go-http-client/1.1          1
# 1      101.180.23.34  python-requests/2.25.1          1
# 2      101.197.18.17  python-requests/2.25.1          1
# 3    101.233.150.110                    nmap          1
# 4      102.197.5.173  python-requests/2.25.1          1
# ..               ...                     ...        ...
# 324    96.94.189.237             curl/7.68.0          1
# 325     97.150.40.17      Go-http-client/1.1          1
# 326    97.189.226.55      Go-http-client/1.1          1
# 327     97.206.0.167  python-requests/2.25.1          1
# 328      97.6.75.191  python-requests/2.25.1          1
#
# [329 rows x 3 columns]

# %%
# Look for suspicious user_agents

# %%
query = """
SELECT ip_address, endpoint, user_agent, timestamp
FROM access_logs

WHERE ( user_agent LIKE '%curl%'
   OR user_agent LIKE '%python%'
   OR user_agent LIKE '%nmap%'
   OR user_agent LIKE '%Go-http-client%'
)
AND (
    endpoint = '/admin' OR
    endpoint = '/login' OR
    endpoint = '/settings'
)
ORDER BY ip_address, timestamp
"""

targeted_bot_activity = pd.read_sql_query(query, conn)
targeted_bot_activity
# Out:
#          ip_address   endpoint              user_agent            timestamp
# 0     101.197.18.17  /settings  python-requests/2.25.1  2025-08-05 12:30:06
# 1     102.197.5.173  /settings  python-requests/2.25.1  2025-08-05 12:56:57
# 2    103.30.157.142     /login                    nmap  2025-08-05 12:15:52
# 3    104.70.217.100  /settings                    nmap  2025-08-05 12:45:49
# 4     107.17.229.73  /settings                    nmap  2025-08-05 12:01:36
# ..              ...        ...                     ...                  ...
# 107   95.162.242.83  /settings      Go-http-client/1.1  2025-08-05 12:50:43
# 108      95.9.37.68     /login  python-requests/2.25.1  2025-08-05 12:00:39
# 109  96.168.122.197     /login  python-requests/2.25.1  2025-08-05 12:44:48
# 110    97.150.40.17  /settings      Go-http-client/1.1  2025-08-05 12:11:43
# 111   97.189.226.55  /settings      Go-http-client/1.1  2025-08-05 12:36:07
#
# [112 rows x 4 columns]

# %%
# show IPs that used suspicious user_agents and accessed senstive endpoints

# %%
targeted_bot_activity.to_csv("flagged_bot_activity.csv", index=False)

# %%
# send out to csv

# %%
targeted_bot_activity["timestamp"] = pd.to_datetime(targeted_bot_activity["timestamp"])

# %%
# convert timestamp to datetime

# %%
requests_per_minute = targeted_bot_activity.groupby(
    targeted_bot_activity["timestamp"].dt.floor("min")
).size()
    
# Plot
plt.figure(figsize=(12, 6))
requests_per_minute.plot(kind='bar', width=0.8)
plt.title("Suspicious Bot Requests per Minute")
plt.xlabel("Timestamp (minute)")
plt.ylabel("Number of Requests")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[199], line 9
#       7 requests_per_minute.plot(kind='bar', width=0.8)
#       8 plt.title("Suspicious Bot Requests per Minute")
# ----> 9 plt.xlablel("Timestamp (minute)")
#      10 plt.ylabel("Number of Requests")
#      11 plt.xticks(rotation=45, ha='right')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlablel'
